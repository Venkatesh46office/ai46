# %%
import pandas as pd
df=pd.read_csv("C:/Users/bhava/AppData/Roaming/Microsoft/Windows/Network Shortcuts/data.csv")
print(df)
# Out:
#    slno           states    bcg  opv3  dpt3  mcast  help  full
# 0     1      a n is land   87.4  83.9  83.5   76.4  83.1  73.2
# 1     2  andhra Prandesh   97.3  72.3  89.0   89.4  68.8  65.2
# 2     3            bihar   82.3  56.0  66.5   71.4  52.0  61.7
# 3     4              goa   91.7  72.9  80.2   79.4  65.0  88.4
# 4     5          haryana  100.0  92.9  94.2   96.5  85.0  62.7

# %%
df.describe()
# Out:
#            slno         bcg       opv3      dpt3      mcast       help  \
# count  5.000000    5.000000   5.000000   5.00000   5.000000   5.000000
# mean   3.000000   91.740000  75.600000  82.68000  82.620000  70.780000
# std    1.581139    7.195346  13.879121  10.50319  10.168186  13.638255
# min    1.000000   82.300000  56.000000  66.50000  71.400000  52.000000
# 25%    2.000000   87.400000  72.300000  80.20000  76.400000  65.000000
# 50%    3.000000   91.700000  72.900000  83.50000  79.400000  68.800000
# 75%    4.000000   97.300000  83.900000  89.00000  89.400000  83.100000
# max    5.000000  100.000000  92.900000  94.20000  96.500000  85.000000
#
#             full
# count   5.000000
# mean   70.240000
# std    11.110041
# min    61.700000
# 25%    62.700000
# 50%    65.200000
# 75%    73.200000
# max    88.400000

# %%
df.tail()
# Out:
#    slno           states    bcg  opv3  dpt3  mcast  help  full
# 0     1      a n is land   87.4  83.9  83.5   76.4  83.1  73.2
# 1     2  andhra Prandesh   97.3  72.3  89.0   89.4  68.8  65.2
# 2     3            bihar   82.3  56.0  66.5   71.4  52.0  61.7
# 3     4              goa   91.7  72.9  80.2   79.4  65.0  88.4
# 4     5          haryana  100.0  92.9  94.2   96.5  85.0  62.7

# %%
df.head()
# Out:
#    slno           states    bcg  opv3  dpt3  mcast  help  full
# 0     1      a n is land   87.4  83.9  83.5   76.4  83.1  73.2
# 1     2  andhra Prandesh   97.3  72.3  89.0   89.4  68.8  65.2
# 2     3            bihar   82.3  56.0  66.5   71.4  52.0  61.7
# 3     4              goa   91.7  72.9  80.2   79.4  65.0  88.4
# 4     5          haryana  100.0  92.9  94.2   96.5  85.0  62.7

# %%
new_data=df['bcg'].mean()
print(new_data)
# Out:
# 91.74

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   slno    5 non-null      int64
#  1   states  5 non-null      object
#  2   bcg     5 non-null      float64
#  3   opv3    5 non-null      float64
#  4   dpt3    5 non-null      float64
#  5   mcast   5 non-null      float64
#  6   help    5 non-null      float64
#  7   full    5 non-null      float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
import matplotlib.pyplot as plt
plt.hist(df['bcg'])
plt.show()
